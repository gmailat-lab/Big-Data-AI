# %%
from google.colab import drive
import pandas as pd

# %%
keyfacial_df = pd.read_csv('/content/data(1).csv')
keyfacial_df
# Out:
#       left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0             66.033564          39.002274           30.227008
# 1             64.332936          34.970077           29.949277
# 2             65.057053          34.909642           30.903789
# 3             65.225739          37.261774           32.023096
# 4             66.725301          39.621261           32.244810
# ...                 ...                ...                 ...
# 2135          67.180378          35.816373           33.239956
# 2136          65.724490          36.301020           25.377551
# 2137          68.430866          38.651975           28.895857
# 2138          64.152180          30.691592           27.000898
# 2139          66.683755          34.483429           30.784490
#
#       right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0              36.421678                59.582075                39.647423
# ...

# %%
import matplotlib.pyplot as plt

# %%
keyfacial_df['Image'].shape
# Out:
# (2140,)

# %%
keyfacial_df['Image'].shape[0]
# Out:
# 2140

# %%
import numpy as np

# %%
keyfacial_df['Image'] = keyfacial_df['Image'].apply(lambda x: np.fromstring(x, dtype = int, sep = ' ').reshape(96,96))

# %%
keyfacial_df['Image'][0].shape
# Out:
# (96, 96)

# %%
keyfacial_df['right_eye_center_x'].mean()
keyfacial_df['right_eye_center_x'].min()
keyfacial_df['right_eye_center_x'].max()
# Out:
# 42.495171727

# %%
i=0
i=np.random.randint(i, len(keyfacial_df)-1)
plt.imshow(keyfacial_df.Image[i], cmap='gray')

# %%
i=0
for j in range (1,31,2):
  plt.plot(keyfacial_df.loc[i][j-1],keyfacial_df.loc[i][j], 'bx')
plt.imshow(keyfacial_df.Image[i], cmap='gray')

# %%
i=0
for j in range (1,31,2):
  plt.plot(keyfacial_df.loc[i][j-1],keyfacial_df.loc[i][j], 'bx')
plt.imshow(keyfacial_df.Image[i], cmap='gray')

# %%
fig, axs = plt.subplots(4,4, i+1)

for i, img in enumerate(keyfacial_df.loc[i]):
# Out:
#   File "<ipython-input-37-7b8c140ccda1>", line 4
#
#     ^
# SyntaxError: incomplete input

# %%
fig=plt.figure(figsize=(15,15))

for i in range(16):
  plt.subplot(4,4,i+1)
  image=plt.imshow(keyfacial_df['Image'][i],cmap= 'gray')
  for j in range(1,31,2):
    plt.plot(keyfacial_df.loc[i][j-1], keyfacial_df.loc[i][j], 'rx')

# %%
fig=plt.figure(figsize=(15,15))
i=np.random.randint(i, len(keyfacial_df)-1)
for i in range(64):


  plt.subplot(8,8,i+1)
  image=plt.imshow(keyfacial_df['Image'][i],cmap= 'gray')
  for j in range(1,31,2):
    plt.plot(keyfacial_df.loc[i][j-1], keyfacial_df.loc[i][j], 'rx')

# %%
import copy
keyfacial_df_copy=copy.copy(keyfacial_df)

# %%
keyfacial_df_copy['Image']=keyfacial_df_copy['Image'].apply(lambda x:np.flip(x))

# %%
plt.imshow(keyfacial_df_copy['Image'][0], cmap='gray')

# %%
for i in range(31):
  if i%2==0:
    keyfacial_df_copy.loc[i]=keyfacial_df_copy.iloc[i].apply(lambda x: 96. -(x))

# %%
keyfacial_df_copy
# Out:
#       left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0             66.033564          39.002274           30.227008
# 1             64.332936          34.970077           29.949277
# 2             65.057053          34.909642           30.903789
# 3             65.225739          37.261774           32.023096
# 4             66.725301          39.621261           32.244810
# ...                 ...                ...                 ...
# 2135          67.180378          35.816373           33.239956
# 2136          65.724490          36.301020           25.377551
# 2137          68.430866          38.651975           28.895857
# 2138          64.152180          30.691592           27.000898
# 2139          66.683755          34.483429           30.784490
#
#       right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0              36.421678                59.582075                39.647423
# ...

# %%
plt.imshow(keyfacial_df_copy['Image'][0],cmap='gray')
for j in range(1,31,2):
  plt.plot(keyfacial_df.loc[i][j-1],keyfacial_df_copy.loc[0][j], 'rx')
